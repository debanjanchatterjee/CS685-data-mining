# %%
import json
import pandas as pd
import csv
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
f=open('neighbor-districts.json')
data=json.load(f)
#print(data)
district=list()
for k in data.keys():
   district.append(k)
print(len(district))


f.close()
# Out:
# 723

# %%
district.sort()
dist_map=dict()
enc=101

for x in district:
    dist_map[x]=enc
    enc+=1

# %%
#dist_cases_covid = pd.read_csv("district_wise.csv")
#dataset=dist_cases_covid.iloc[:,4:6].values;
#print(dataset)

# %%
f2=open('data-all.json')
dataset=json.load(f2)
f2.close()
#print(dataset['2020-06-02']['AP']['districts']['Anantapur']['delta']['confirmed'])
#print(dataset['2020-03-15'])

# %%
#creating states and district list from data-all.json

days2020=[range(30,32),range(1,30),range(15,32),range(1,31),range(1,32),range(1,31),range(1,32),range(1,32),range(1,6),range(1,32),range(1,31),range(1,32)]
year='2020'
dist_covid=set()
state_covid=dict()

day=30
for month in range(3, 10):
    for day in days2020[month-1]:
        if(month<10):
            smonth='0'+str(month)
        else:
            smonth=str(month)
        if(day<10):
            sday='0'+str(day)
        else:
            sday=str(day)
        x=year+'-'+smonth+'-'+sday
        for states in dataset[x].keys():
            state_covid[states]=set()
            d=dataset[x][states]
            if 'districts' in d.keys():
                for keys in d['districts'].keys():
                    dist_covid.add(keys)
                    state_covid[states].add(keys)
        
#print(state_covid.keys())
l=0
for i in state_covid:
   l=l+len(state_covid[i])

print(l)
# Out:
# 653

# %%
#creating state code map
#preprocessing

fstate=open("IndianStates.json")
state_code=json.load(fstate)
fstate.close()



#print(len(state_code))

print(state_code)


del state_code['TS']
del state_code['UK']
del state_code['CH']
del state_code['CG']


state_code['TG']='Telangana'
state_code['TT']='Total'
state_code['UT']='Uttarakhand'
state_code['CH']='Chandigarh'
state_code['CT']='Chattisgarh'
state_code['UN']='Unknown'


#print(state_code)

#print(len(state_covid))
# Out:
# {'AN': 'Andaman and Nicobar Islands', 'AP': 'Andhra Pradesh', 'AR': 'Arunachal Pradesh', 'AS': 'Assam', 'BR': 'Bihar', 'CG': 'Chandigarh', 'CH': 'Chhattisgarh', 'DN': 'Dadra and Nagar Haveli', 'DD': 'Daman and Diu', 'DL': 'Delhi', 'GA': 'Goa', 'GJ': 'Gujarat', 'HR': 'Haryana', 'HP': 'Himachal Pradesh', 'JK': 'Jammu and Kashmir', 'JH': 'Jharkhand', 'KA': 'Karnataka', 'KL': 'Kerala', 'LA': 'Ladakh', 'LD': 'Lakshadweep', 'MP': 'Madhya Pradesh', 'MH': 'Maharashtra', 'MN': 'Manipur', 'ML': 'Meghalaya', 'MZ': 'Mizoram', 'NL': 'Nagaland', 'OR': 'Odisha', 'PY': 'Puducherry', 'PB': 'Punjab', 'RJ': 'Rajasthan', 'SK': 'Sikkim', 'TN': 'Tamil Nadu', 'TS': 'Telangana', 'TR': 'Tripura', 'UP': 'Uttar Pradesh', 'UK': 'Uttarakhand', 'WB': 'West Bengal'}

# %%
#preprocessing state_covid




dist_state=list()

for states in state_covid:
    for districts in state_covid[states]:
        if districts=='Unknown':
            districts=state_code[states]
        dist_state.append(districts+'_'+states)
     
        
#print(c)
print(len(dist_state))
# Out:
# 653

# %%
#finding states with same names in neighbors

#dist_covid=list(dist_covid)
index=0
c=0
#highest = process.extractOne('palghat',dist_covid)
identical_dist=list()

for districts in district:
    d=districts.split('/')
    district_name=d[0]
    for j in district[c+1:]:
        jarr=j.split('/')
        if jarr[0]==district_name:
            identical_dist.append(jarr[0])
            print(jarr)
            print(d)
            
    c=c+1
# Out:
# ['aurangabad', 'Q592942']
# ['aurangabad', 'Q43086']
# ['balrampur', 'Q1948380']
# ['balrampur', 'Q16056268']
# ['bilaspur', 'Q1478939']
# ['bilaspur', 'Q100157']
# ['hamirpur', 'Q2086180']
# ['hamirpur', 'Q2019757']
# ['pratapgarh', 'Q1585433']
# ['pratapgarh', 'Q1473962']

# %%
#finding name 

#"jyotiba_phule_nagar/Q1891677" -> "Amroha"

#"sant_ravidas_nagar/Q127533" -> "Bhadohi"

#"bijapur_district/Q1727570" -> "Vijayapura"

#"palghat/Q1535742" -> "Palakkad"

#"faizabad/Q1814132" ->  "Ayodhya"

print(data['aurangabad/Q43086'])
print(data['bilaspur/Q100157'])
        
identicalmap=dict()

identicalmap['bilaspur/Q1478939']='HP'
# Out:
# ['arwal/Q42917', 'gaya/Q49173', 'palamu/Q1797254', 'rohtas/Q100085']
# ['mungeli/Q13476249', 'baloda_bazar/Q15663455', 'korba/Q2299121', 'anuppur/Q2299093', 'janjgir-champa/Q2575633', 'koriya/Q2295896']

# %%
#finding closest match
#print(district)

#highest = process.extractOne('gondia/Q1917227' ,district) ---->   ('gondiya/Q1917227', 97)

highest = process.extractOne("bhadohi/Q127533" ,district)
print(highest)

test=list()
for i in state_covid['SK']:
    m= process.extractOne(i,district)
    test.append(m[0])
    print('da2nd["'+i+'_SK"]'+'='+'"'+m[0]+'"')

print(state_covid['SK'])
print(state_covid.keys())
# Out:
# ('sant_ravidas_nagar/Q127533', 86)
# da2nd["Unknown_SK"]="lucknow/Q1773416"
# {'Unknown'}
# dict_keys(['AP', 'DL', 'HP', 'HR', 'JK', 'KA', 'KL', 'LA', 'MH', 'PB', 'RJ', 'TG', 'TN', 'TT', 'UP', 'UT', 'OR', 'PY', 'WB', 'CH', 'CT', 'GJ', 'MP', 'BR', 'MN', 'GA', 'MZ', 'AN', 'AS', 'JH', 'AR', 'NL', 'TR', 'DN', 'ML', 'SK', 'UN'])

# %%
#mapping
da2nd=dict()

#state's districts to be merged: DL, TG, MN, GA, AN, AS, SK







#ML
da2nd["East Jaintia Hills_ML"]="east_jaintia_hills/Q15923776"
da2nd["West Khasi Hills_ML"]="west_khasi_hills/Q2064752"
da2nd["Ribhoi_ML"]="ri-bhoi/Q1884672"
da2nd["East Khasi Hills_ML"]="east_khasi_hills/Q1945304"
da2nd["South Garo Hills_ML"]="south_garo_hills/Q2329228"
da2nd["East Garo Hills_ML"]="east_garo_hills/Q2085455"
da2nd["West Garo Hills_ML"]="west_garo_hills/Q2329181"
da2nd["West Jaintia Hills_ML"]="west_jaintia_hills/Q1920789"
da2nd["Fatehabad_HR"]="fatehabad/Q2301753"
da2nd["Bhiwani_HR"]="bhiwani_district/Q1852857"
da2nd["Sirsa_HR"]="sirsa/Q526101"
da2nd["Panipat_HR"]="panipat/Q2086163"
da2nd["Charkhi Dadri_HR"]="charkhi_dadri/Q28172110"
da2nd["Kaithal_HR"]="kaithal/Q614037"
da2nd["Nuh_HR"]="nuh/Q2216696"
da2nd["Hisar_HR"]="hisar/Q1815773"
da2nd["Jhajjar_HR"]="jhajjar/Q1948260"
da2nd["Faridabad_HR"]="faridabad/Q2086173"






#HP
da2nd['Sirmaur_HP']='sirmaur/Q654331'
da2nd['Kinnaur_HP']='kinnaur/Q1862950'
da2nd['Bilaspur_HP']='bilaspur/Q1478939'
da2nd['Una_HP']='una/Q2301741'
da2nd['Lahaul and Spiti_HP']='lahul_and_spiti/Q837595'
da2nd['Kullu_HP']='kullu/Q2980880'
da2nd['Kangra_HP']='kangra/Q727232'
da2nd['Hamirpur_HP']='hamirpur/Q2086180'
da2nd['Shimla_HP']='shimla/Q1921404'
da2nd['Chamba_HP']='chamba/Q1060614'
da2nd['Mandi_HP']='mandi/Q1892161'
da2nd['Solan_HP']='solan/Q2980937'






#AP
da2nd['S.P.S. Nellore_AP']='sri_potti_sriramulu_nellore/Q15383'
da2nd['Krishna_AP']='krishna/Q15382'
da2nd['Srikakulam_AP']='srikakulam/Q15395'
da2nd['Y.S.R. Kadapa_AP']='ysr/Q15342'
da2nd['Chittoor_AP']='chittoor/Q15213'
da2nd['Vizianagaram_AP']='vizianagaram/Q15392'
da2nd['West Godavari_AP']='west_godavari/Q15404'
da2nd['Kurnool_AP']='kurnool/Q15381'
da2nd['Prakasam_AP']='prakasam/Q15390'
da2nd['Visakhapatnam_AP']='visakhapatnam/Q15394'
da2nd['East Godavari_AP']='east_godavari/Q15338'
da2nd['Anantapur_AP']='anantapur_district/Q15212'
da2nd['Guntur_AP']='guntur/Q15341'







print(len(da2nd))
#print(da2nd)


nd2da=dict()

for i in da2nd:
    if da2nd[i] in nd2da.keys():
        print(da2nd[i])
        print(i)
    nd2da[da2nd[i]]=i
    
print(len(nd2da))
# Out:
# 621
# 621

# %%
#sorting our the rest



leftout=list()
for x in district:
    if x not in nd2da.keys():
        leftout.append(x)
        
print(len(leftout))

#print(leftout)

print(data["noklak/Q48731903"])
#for x in leftout:
#    print('merged["'+x+'"]=')
# Out:
# 102
# ['mon/Q2339648', 'tuensang/Q2571393']

# %%
#still preprocessing


merged=dict()

merged["kokrajhar/Q42618"]="Assam_AS"
merged["dhubri/Q42485"]='Assam_AS'
merged["bongaigaon/Q42197"]='Assam_AS'
merged["chirang/Q2574898"]='Assam_AS'
merged["south_sikkim_district/Q1805051"]='Sikkim_SK'
merged["west_sikkim_district/Q611357"]='Sikkim_SK'
merged["east_sikkim_district/Q1772832"]='Sikkim_SK'
merged["north_sikkim_district/Q1784149"]="Sikkim_SK"
merged["barpeta/Q41249"]='Assam_AS'
merged["goalpara/Q42522"]='Assam_AS'
merged["dima_hasao_district/Q42774"]="Assam_AS"
merged["golaghat/Q42517"]="Assam_AS"
merged["hojai/Q24699407"]="Assam_AS"
merged["cachar/Q42209"]="Assam_AS"
merged["tamenglong/Q2301717"]="Manipur_MN"
merged["hailakandi/Q42505"]="Assam_AS"
merged["karimganj/Q42542"]="Assam_AS"
merged["jiribam/Q28419387"]="Manipur_MN"
merged["pherzawl/Q28173809"]="Manipur_MN"
merged["bishwanath/Q28110722"]="Assam_AS"
merged["jorhat/Q42611"]="Assam_AS"
merged["majuli/Q28110729"]="Assam_AS"
merged["sivasagar/Q42768"]="Assam_AS"
merged["dhemaji/Q42473"]="Assam_AS"
merged["dibrugarh/Q42479"]="Assam_AS"
merged["tinsukia/Q42756"]="Assam_AS"
merged["charaideo/Q24039029"]="Assam_AS"
merged["churachandpur/Q2577281"]="Manipur_MN"
merged["bishnupur/Q938190"]="Manipur_MN"
merged["chandel/Q2301769"]="Manipur_MN"
merged["noney/Q28419389"]="Manipur_MN"
merged["kakching/Q28173825"]="Manipur_MN"
merged["imphal_east/Q1916666"]="Manipur_MN"
merged["imphal_west/Q1822188"]="Manipur_MN"
merged["thoubal/Q2086198"]="Manipur_MN"
merged["kangpokpi/Q28419386"]="Manipur_MN"
merged["senapati/Q2301706"]="Manipur_MN"
merged["ukhrul/Q735101"]="Manipur_MN"
merged["tengnoupal/Q28419388"]="Manipur_MN"
merged["kamjong/Q28419390"]="Manipur_MN"
merged["noklak/Q48731903"]="Tuensang_NL"
merged["mulugu/Q61746006"]="Telangana_TG"
merged["mumbai_suburban/Q2085374"]='Mumbai_MH'


print(len(merged))

merged_rev=dict()
for i in merged.keys():
    merged_rev[merged[i]]=i

print(len(merged_rev))
print(merged_rev)
# Out:
# 102
# 9
# {'Assam_AS': 'charaideo/Q24039029', 'Sikkim_SK': 'north_sikkim_district/Q1784149', 'Delhi_DL': 'south_delhi/Q2061938', 'Mumbai_MH': 'mumbai_suburban/Q2085374', 'Hardoi_UP': 'kheri/Q1755447', 'Telangana_TG': 'mulugu/Q61746006', 'Goa_GA': 'south_goa/Q108244', 'Manipur_MN': 'kamjong/Q28419390', 'Tuensang_NL': 'noklak/Q48731903'}

# %%
# generating neighbor-districts-modified.json using the preprocessed data



#merged and nd2da

#first merging

modified=dict()

for key in data.keys():
    
    if key in nd2da.keys():
        new_key=nd2da[key]
    else:
        new_key=merged[key]
    
    if new_key in modified.keys():
        modified[new_key].extend(data[key])
        temp=set(modified[new_key])
        modified[new_key]=list(temp)
    
    else:
        modified[new_key]=data[key]
    
    
    
    for neighbors in modified[new_key]:
        if neighbors in da2nd.keys() or neighbors in merged_rev.keys():
            if neighbors==new_key:
                modified[new_key].remove(neighbors)
            continue
        
        if neighbors in nd2da.keys():
            new_name=nd2da[neighbors]
        else:
            new_name=merged[neighbors]
        
        if new_name!=new_key:
            modified[new_key].remove(neighbors)
            modified[new_key].append(new_name)
        else:
            modified[new_key].remove(neighbors)
        
    temp2=set(modified[new_key])
    modified[new_key]=list(temp2)
    
            
print(len(data))
print(len(modified))




print(modified)
#print(modified.keys())
# Out:
# 723
# 627
# ...

# %%
#some cleaning

for x in modified.keys():
    for y in modified[x]:
        if '_' not in y:
            modified[x].remove(y)
            if y in nd2da.keys():
                modified[x].append(nd2da[y])
            else:
                modified[x].append(merged[y])
         
  # "leh_district/Q1921210"     
print(modified)
# Out:
# {'Lahaul and Spiti_HP': ['Leh_LA', 'kargil_district/Q1650798', 'Kullu_HP', 'Chamba_HP', 'Kishtwar_JK', 'Kangra_HP', 'Kinnaur_HP'], 'Kinnaur_HP': ['Kullu_HP', 'lahul_and_spiti/Q837595', 'Uttarkashi_UT', 'Shimla_HP'], 'Kullu_HP': ['lahul_and_spiti/Q837595', 'Shimla_HP', 'Mandi_HP', 'Kinnaur_HP', 'Kangra_HP'], 'Chamba_HP': ['Lahaul and Spiti_HP', 'kathua/Q2375700', 'Doda_JK', 'Kishtwar_JK', 'Kangra_HP', 'Pathankot_PB'], 'Kangra_HP': ['lahul_and_spiti/Q837595', 'Hoshiarpur_PB', 'Gurdaspur_PB', 'pathankot/Q172269', 'Hamirpur_HP', 'Kullu_HP', 'Chamba_HP', 'Mandi_HP', 'Una_HP'], 'Leh_LA': ['Lahaul and Spiti_HP', 'kargil_district/Q1650798'], 'Kargil_LA': ['Ganderbal_JK', 'Lahaul and Spiti_HP', 'leh_district/Q1921210', 'Anantnag_JK', 'Bandipora_JK', 'Kishtwar_JK'], 'Kishtwar_JK': ['lahul_and_spiti/Q837595', 'Kargil_LA', 'Chamba_HP', 'Anantnag_JK', 'Doda_JK'], 'Shimla_HP': ['Kullu_HP', 'Mandi_HP', 'Sirmaur_HP', 'Uttarkashi_UT', 'Dehradun_UT', 'Kinnaur_HP', 'Solan_HP'], 'Uttarkashi_UT': ['tehri
# ...

# %%
for x in modified.keys():
    for y in modified[x]:
        if '/' in y:
            modified[x].remove(y)
            if y in nd2da.keys():
                modified[x].append(nd2da[y])
            else:
                modified[x].append(merged[y])
    t=set(modified[x])
    modified[x]=list(t)
         
  # "leh_district/Q1921210"   
print(merged['south_sikkim_district/Q1805051'])
print(modified['Kalimpong_WB'])
print(modified)
# Out:
# Sikkim_SK
# ['east_sikkim_district/Q1772832', 'Sikkim_SK', 'Jalpaiguri_WB', 'Darjeeling_WB']
# ...

# %%
# adding 3 digit ids:
count=101
code_map=dict()
dist_mod_sort=list()
for x in modified.keys():
    dist_mod_sort.append(x)


list.sort(dist_mod_sort)

for i in dist_mod_sort:
    code_map[i]=count
    count=count+1

print(code_map)
# Out:
# {'Agar Malwa_MP': 101, 'Agra_UP': 102, 'Ahmedabad_GJ': 103, 'Ahmednagar_MH': 104, 'Aizawl_MZ': 105, 'Ajmer_RJ': 106, 'Akola_MH': 107, 'Alappuzha_KL': 108, 'Aligarh_UP': 109, 'Alipurduar_WB': 110, 'Alirajpur_MP': 111, 'Almora_UT': 112, 'Alwar_RJ': 113, 'Ambala_HR': 114, 'Ambedkar Nagar_UP': 115, 'Amethi_UP': 116, 'Amravati_MH': 117, 'Amreli_GJ': 118, 'Amritsar_PB': 119, 'Amroha_UP': 120, 'Anand_GJ': 121, 'Anantapur_AP': 122, 'Anantnag_JK': 123, 'Angul_OR': 124, 'Anjaw_AR': 125, 'Anuppur_MP': 126, 'Araria_BR': 127, 'Aravalli_GJ': 128, 'Ariyalur_TN': 129, 'Arwal_BR': 130, 'Ashoknagar_MP': 131, 'Assam_AS': 132, 'Auraiya_UP': 133, 'Aurangabad_BR': 134, 'Aurangabad_MH': 135, 'Ayodhya_UP': 136, 'Azamgarh_UP': 137, 'Bagalkote_KA': 138, 'Bageshwar_UT': 139, 'Baghpat_UP': 140, 'Bahraich_UP': 141, 'Balaghat_MP': 142, 'Balangir_OR': 143, 'Balasore_OR': 144, 'Ballari_KA': 145, 'Ballia_UP': 146, 'Balod_CT': 147, 'Baloda Bazar_CT': 148, 'Balrampur_CT': 149, 'Balrampur_UP': 150, 'Bametara_CT': 151, 
# ...

# %%
#saving district encoding into json

with open('code_map.json', 'w') as fp1:
    json.dump(code_map, fp1)

# %%
print(len(modified.keys()))
for x in modified.keys():
    new_x=''
    if '/' in x:
        continue
    new_x=x+'/'+str(code_map[x])
    
    modified[new_x]=modified.pop(x)
    temp=list()
    for y in modified[new_x]:
        if '/' not in y:
            temp.append(y+'/'+str(code_map[y]))
        else:
            temp.append(y)
    
    modified[new_x]=temp
print(len(modified.keys()))
print(modified)
# Out:
# 627
# 627
# ...

# %%
#saving modified neighbors district into json

with open('neighbor-districts-modified.json', 'w') as fp:
    json.dump(modified, fp)
fp.close()

# %%
#saving modified neighbors district into json

with open('nd2da.json', 'w') as fp2:
    json.dump(nd2da, fp2)

# %%
#saving modified neighbors district into json

with open('merged.json', 'w') as fp3:
    json.dump(merged, fp3)

# %%
#Question 2
#overall number of cases



#print(dist_covid)
#print(dataset['2020-06-02']['UN'])

overall_cases=dict()

for month in range(3, 10):
    for day in days2020[month-1]:
        if(month<10):
            smonth='0'+str(month)
        else:
            smonth=str(month)
        if(day<10):
            sday='0'+str(day)
        else:
            sday=str(day)
        x=year+'-'+smonth+'-'+sday
        #print(x)
        for states in dataset[x].keys():
            d=dataset[x][states]
            if 'districts' in d.keys():
                for keys in d['districts'].keys():
                    if 'delta' in dataset[x][states]['districts'][keys].keys():
                        if 'confirmed' in dataset[x][states]['districts'][keys]['delta'].keys():
                                if keys+'_'+states in overall_cases.keys():
                                    overall_cases[keys+'_'+states]=overall_cases[keys+'_'+states]+dataset[x][states]['districts'][keys]['delta']['confirmed']
                                    #overall_cases[states][keys][1]=overall_cases[states][keys][1]+dataset[x][states]['districts'][keys]['delta']['confirmed']
                                else:
                                    #print(keys+ states)
                                    overall_cases[keys+'_'+states]=dataset[x][states]['districts'][keys]['delta']['confirmed']
                                    #overall_cases[states][keys][1]=dataset[x][states]['districts'][keys]['delta']['confirmed']
                            
                            
                    
#print(overall_cases)
total=0
for x in overall_cases.keys():
    total=total+overall_cases[x]
#print(total)

#print(len(overall_cases))

# %%
#question 2
#monthly cases


monthly_cases=dict()
month_id=1
for month in range(3, 10):
    for day in days2020[month-1]:
        if(month<10):
            smonth='0'+str(month)
        else:
            smonth=str(month)
        if(day<10):
            sday='0'+str(day)
        else:
            sday=str(day)
        x=year+'-'+smonth+'-'+sday
        #print(x)
        for states in dataset[x].keys():
            d=dataset[x][states]
            if 'districts' in d.keys():
                for keys in d['districts'].keys():
                    if 'delta' in dataset[x][states]['districts'][keys].keys():
                        if 'confirmed' in dataset[x][states]['districts'][keys]['delta'].keys():
                                if keys+'_'+states in monthly_cases.keys():
                                    if month_id not in monthly_cases[keys+'_'+states].keys():
                                        monthly_cases[keys+'_'+states][month_id]=dataset[x][states]['districts'][keys]['delta']['confirmed']
                                        
                                    monthly_cases[keys+'_'+states][month_id]=monthly_cases[keys+'_'+states][month_id]+dataset[x][states]['districts'][keys]['delta']['confirmed']
                                    
                                else:
                                    monthly_cases[keys+'_'+states]=dict()
                                    #if month_id not in monthly_cases[keys+'_'+states].keys():
                                    #    overall_cases[keys+'_'+states][month_id]=0
                                   
                                    monthly_cases[keys+'_'+states][month_id]=dataset[x][states]['districts'][keys]['delta']['confirmed']
                                    
                                    
                                    
                                    
    month_id=month_id+1

                                    
print(monthly_cases)
# Out:
# {'Unknown_TG': {1: 95, 2: 971, 3: 1666, 4: 13735, 5: 47382, 6: 64343, 7: 16166}, 'Delhi_DL': {1: 113, 2: 3427, 3: 16552, 4: 68506, 5: 50680, 6: 40268, 7: 15757}, 'Chandigarh_CH': {1: 15, 2: 61, 3: 233, 4: 151, 5: 617, 6: 3323, 7: 1360}, 'Unknown_MN': {1: 1, 2: 2, 3: 70, 4: 1175, 5: 1413, 6: 3766, 7: 761}, 'Unknown_GA': {1: 5, 2: 3, 3: 72, 4: 1246, 5: 4670, 6: 11785, 7: 3625}, 'Unknown_AN': {1: 10, 2: 24, 4: 65, 5: 454, 6: 2672, 7: 188}, 'Unknown_AS': {1: 1, 2: 57, 3: 1299, 4: 7214, 5: 32410, 6: 70228, 7: 17566}, 'Guntur_AP': {2: 73, 3: 221, 4: 867, 5: 13396, 6: 22094, 7: 4288}, 'Krishna_AP': {2: 69, 3: 236, 4: 1004, 5: 5428, 6: 9798, 7: 2052}, 'Kurnool_AP': {2: 107, 3: 362, 4: 1233, 5: 14982, 6: 29132, 7: 4074}, 'S.P.S. Nellore_AP': {2: 12, 3: 161, 4: 385, 5: 6741, 6: 23923, 7: 6358}, 'Srikakulam_AP': {2: 2, 3: 20, 4: 45, 5: 6537, 6: 17963, 7: 3717}, 'West Godavari_AP': {2: 5, 3: 45, 4: 904, 5: 11330, 6: 25290, 7: 5644}, 'Aurangabad_BR': {2: 6, 3: 71, 4: 157, 5: 712, 6: 1830, 7: 288}
# ...

# %%
#question2
#weekly cases


weekly_cases=dict()
week_id=1
counter=1
for month in range(3, 10):
    for day in days2020[month-1]:
        if(month<10):
            smonth='0'+str(month)
        else:
            smonth=str(month)
        if(day<10):
            sday='0'+str(day)
        else:
            sday=str(day)
        x=year+'-'+smonth+'-'+sday
        #print(x)
        for states in dataset[x].keys():
            d=dataset[x][states]
            if 'districts' in d.keys():
                for keys in d['districts'].keys():
                    if 'delta' in dataset[x][states]['districts'][keys].keys():
                        if 'confirmed' in dataset[x][states]['districts'][keys]['delta'].keys():
                                if keys+'_'+states in weekly_cases.keys():
                                    if week_id not in weekly_cases[keys+'_'+states].keys():
                                        #weekly_cases[keys+'_'+states][week_id]=dataset[x][states]['districts'][keys]['delta']['confirmed']
                                        weekly_cases[keys+'_'+states][week_id]=0
                                    weekly_cases[keys+'_'+states][week_id]=weekly_cases[keys+'_'+states][week_id]+dataset[x][states]['districts'][keys]['delta']['confirmed']
                                    
                                else:
                                    weekly_cases[keys+'_'+states]=dict()
                                    #if month_id not in monthly_cases[keys+'_'+states].keys():
                                    #    overall_cases[keys+'_'+states][month_id]=0
                                   
                                    weekly_cases[keys+'_'+states][week_id]=dataset[x][states]['districts'][keys]['delta']['confirmed']
                                    
                                    
                                    
                                    
        counter=counter+1
        if counter>7:
            counter=1
            week_id=week_id+1

                                    
print(weekly_cases)
# Out:
# {'Unknown_TG': {1: 19, 2: 46, 3: 205, 4: 231, 5: 306, 6: 181, 7: 71, 8: 102, 9: 346, 10: 304, 11: 686, 12: 997, 13: 1241, 14: 2335, 15: 6364, 16: 8876, 17: 11090, 18: 10378, 19: 10279, 20: 10727, 21: 12727, 22: 12746, 23: 11606, 24: 18301, 25: 18229}, 'Delhi_DL': {1: 20, 2: 22, 3: 396, 4: 624, 5: 824, 6: 732, 7: 1497, 8: 2420, 9: 2791, 10: 3577, 11: 5639, 12: 9105, 13: 11304, 14: 17788, 15: 23442, 16: 17012, 17: 13721, 18: 10661, 19: 7949, 20: 7185, 21: 7411, 22: 7801, 23: 8088, 24: 11350, 25: 16827}, 'Chandigarh_CH': {1: 5, 2: 3, 3: 10, 4: 1, 5: 4, 6: 5, 7: 66, 8: 75, 9: 22, 10: 34, 11: 64, 12: 23, 13: 38, 14: 54, 15: 24, 16: 31, 17: 90, 18: 142, 19: 161, 20: 227, 21: 347, 22: 583, 23: 767, 24: 1209, 25: 1517}, 'Unknown_MN': {2: 1, 3: 1, 9: 5, 10: 22, 11: 31, 12: 97, 13: 292, 14: 328, 15: 315, 16: 233, 17: 268, 18: 298, 19: 285, 20: 580, 21: 879, 22: 755, 23: 742, 24: 828, 25: 923}, 'Unknown_GA': {2: 3, 3: 4, 9: 13, 10: 35, 11: 15, 12: 197, 13: 256, 14: 231, 15: 374, 16: 556, 17: 68
# ...

# %%
#testing fuzzywuzzy

dist_covid=list(dist_covid)
index=0

highest = process.extractOne('palghat',dist_covid)
#print(highest)

# %%
#Question 3



f=open('neighbor-districts.json')
adj_list=json.load(f)
edge_list=set()
#print(adj_list)

for district in adj_list.keys():
    for neighbors in adj_list[district]:
        
        edge=[dist_map[district],dist_map[neighbors]]
        
        edge.sort()
        
        edge_list.add(tuple(edge))
        
        
#print(edge_list)
#print(len(edge_list))

# %%
#Question 3 storing into csv file

file = open('edge-graph.csv', 'w+', newline ='') 
with file:     
    write = csv.writer(file) 
    write.writerows(edge_list) 
file.close()
