# %%
import pandas as pd
from urllib.parse import unquote
import csv

# %% [markdown]
# # Doubt : should we print the one with only back edges or all in finished with back

# %%
#finpathsTSV='wikispeedia_paths-and-graph/wikispeedia_paths-and-graph/paths_finished.tsv'
finpathsTSV='paths_finished.tsv'
finpathdf = pd.read_csv(finpathsTSV, sep='\t',names=["hashedip","timestamp","durationinsec","path","rating"])

# %%
finpathlist=finpathdf['path'].values.tolist()

# %%
len(finpathlist)
# Out:
# 51333

# %%
#ss

# %%
#ls=ss.split(";")

# %%
#len(ls)

# %%
#start=ls[0]
#end=ls[8]

# %%
#start

# %%
#end

# %%
articleid = 'article-ids.csv'
article_ids = pd.read_csv(articleid,names=["articleId","article"])

# %%
articleidlist=article_ids['articleId'].values.tolist()

# %%
len(articleidlist)
# Out:
# 4604

# %%
artid_dict=article_ids.set_index('article').T.to_dict('records')

artid_dict=artid_dict[0]

# %%
artid_dict
# Out:
# {'A0001': '%C3%81ed%C3%A1n_mac_Gabr%C3%A1in',
#  'A0002': '%C3%85land',
#  'A0003': '%C3%89douard_Manet',
#  'A0004': '%C3%89ire',
#  'A0005': '%C3%93engus_I_of_the_Picts',
#  'A0006': '%E2%82%AC2_commemorative_coins',
#  'A0007': '10th_century',
#  'A0008': '11th_century',
#  'A0009': '12th_century',
#  'A0010': '13th_century',
#  'A0011': '14th_century',
#  'A0012': '15th_Marine_Expeditionary_Unit',
#  'A0013': '15th_century',
#  'A0014': '16_Cygni',
#  'A0015': '16_Cygni_Bb',
#  'A0016': '16th_century',
#  'A0017': '1755_Lisbon_earthquake',
#  'A0018': '17th_century',
#  'A0019': '1896_Summer_Olympics',
#  'A0020': '18th_century',
#  'A0021': '1928_Okeechobee_Hurricane',
#  'A0022': '1973_oil_crisis',
#  'A0023': '1980_eruption_of_Mount_St._Helens',
#  'A0024': '1997_Pacific_hurricane_season',
#  'A0025': '19th_century',
#  'A0026': '1_Ceres',
#  'A0027': '1st_century',
#  'A0028': '1st_century_BC',
#  'A0029': '2-6-0',
#  'A0030': '2-8-0',
#  'A0031': '2003_Atlantic_hurricane_season',
#  'A0032': '2004_Atlantic_hurricane_season',
#  'A0033': '2004_Indian_Ocean_earthquake',
#  'A0034': '2005_Atlantic_hurricane_season',
#  'A0035': '2005_Hertfordshire_Oil_Storage_Terminal_fire',
#  'A0036': '2005_Kashmir_earthquake',
#  'A0037': '2005_Lake_Tanganyika_earthquake',
#  'A0038': '2005_Sumatra_earthquake',
#  'A0039': '20th_century',
#  'A0040': '21st_century',
#  'A0041': '2nd_century',
#  'A0042': '3_Juno',
#  'A0043': '3rd_century',
#  'A0044': '4-2-0',
#  'A0045': '4-4-0',
#  'A0046': '4-6-0',
#  'A0047': '47_Ursae_Majoris',
#  'A0048': '47_Ursae_Majoris_b',
#  'A0049': '47_Ursae_Majoris_c',
#  'A0050': '4_Vesta',
#  'A0051': '4th_century',
#  'A0052': '55_Cancri',
#  'A0053': '55_Cancri_b',
#  'A0054': '55_Cancri_c',
#  'A0055': '55_Cancri_d',
#  'A0056': '55_Cancri_e',
#  'A0057': '5th_century',
#  'A0058': '6-2-0',
#  'A0059': '6th_century',
#  'A0060': '7th_century',
#  'A0061': '8th_century',
#  'A0062': '90377_Sedna',
#  'A0063': '9th_century',
#  'A0064': 'A._E._J._Collins',
#  'A0065': 'ABO_blood_group_system',
#  'A0066': 'AC_DC',
#  'A0067': 'AIDS',
#  'A0068': 'AK-47',
#  'A0069': 'ALCO_FA',
#  'A0070': 'ASCII',
#  'A0071': 'AT%26T',
#  'A0072': 'ATLAS_experiment',
#  'A0073': 'A_Christmas_Carol',
#  'A0074': 'A_Tale_of_a_Tub',
#  'A0075': 'A_Wrinkle_in_Time',
#  'A0076': 'A_cappella',
#  'A0077': 'Aachen',
#  'A0078': 'Aardvark',
#  'A0079': 'Aarhus',
#  'A0080': 'Abac%C3%A1',
#  'A0081': 'Abacus',
#  'A0082': 'Abadan',
#  'A0083': 'Abbadid',
#  'A0084': 'Abbas_I_of_Persia',
#  'A0085': 'Abbasid',
#  'A0086': 'Abbey',
#  'A0087': 'Abbey_Theatre',
#  'A0088': 'Abbot',
#  'A0089': 'Abel_Tasman',
#  'A0090': 'Aberdeen',
#  'A0091': 'Aberration_of_light',
#  'A0092': 'Aberystwyth',
#  'A0093': 'Abhidhamma_Pitaka',
#  'A0094': 'Abidjan',
#  'A0095': 'Abkhazia',
#  'A0096': 'Able_Archer_83',
#  'A0097': 'Abraham_Goldfaden',
#  'A0098': 'Abraham_Lincoln',
#  'A0099': 'Absinthe',
#  'A0100': 'Absolute_zero',
#  'A0101': 'Abstract_art',
#  'A0102': 'Abu_Dhabi',
#  'A0103': 'Abuja',
#  'A0104': 'Acceleration',
#  'A0105': 'Accountancy',
#  'A0106': 'Accra',
#  'A0107': 'Acetic_acid',
#  'A0108': 'Acetone',
#  'A0109': 'Achilles',
#  'A0110': 'Achilles_tendon',
#  'A0111': 'Acid_rain',
#  'A0112': 'Acorn_Computers',
#  'A0113': 'Actinium',
#  'A0114': 'Action_potential',
#  'A0115': 'Actor',
#  'A0116': 'Acts_of_Union_1707',
#  'A0117': 'Actuary',
#  'A0118': 'Adam_Smith',
#  'A0119': 'Addis_Ababa',
#  'A0120': 'Adelaide',
#  'A0121': 'Adenosine_triphosphate',
#  'A0122': 'Adi_Shankara',
#  'A0123': 'Adolf_Hitler',
#  'A0124': 'Adriaen_van_der_Donck',
#  'A0125': 'Advertising',
#  'A0126': 'Aesthetics',
#  'A0127': 'Afghan_Hound',
#  'A0128': 'Afghanistan',
#  'A0129': 'Africa',
#  'A0130': 'African_American_literature',
#  'A0131': 'African_Black_Oystercatcher',
#  'A0132': 'African_Brush-tailed_Porcupine',
#  'A0133': 'African_Buffalo',
#  'A0134': 'African_Darter',
#  'A0135': 'African_Great_Lakes',
#  'A0136': 'African_Grey_Hornbill',
#  'A0137': 'African_Grey_Parrot',
#  'A0138': 'African_Jacana',
#  'A0139': 'African_Penguin',
#  'A0140': 'African_Union',
#  'A0141': 'African_Wild_Dog',
#  'A0142': 'African_clawed_frog',
#  'A0143': 'African_dwarf_frog',
#  'A0144': 'African_slave_trade',
#  'A0145': 'Afrikaans',
#  'A0146': 'Agamemnon',
#  'A0147': 'Age_of_Enlightenment',
#  'A0148': 'Aggregator',
#  'A0149': 'Agnosticism',
#  'A0150': 'Agriculture',
#  'A0151': 'Airbus',
#  'A0152': 'Airbus_A380',
#  'A0153': 'Aircraft',
#  'A0154': 'Aircraft_carrier',
#  'A0155': 'Airship',
#  'A0156': 'Ajax_%28programming%29',
#  'A0157': 'Akbar',
#  'A0158': 'Akhenaten',
#  'A0159': 'Akira_Kurosawa',
#  'A0160': 'Akkadian_Empire',
#  'A0161': 'Akrotiri_and_Dhekelia',
#  'A0162': 'Aksumite_currency',
#  'A0163': 'Al_Jazeera',
#  'A0164': 'Alamosaurus',
#  'A0165': 'Alan_Turing',
#  'A0166': 'Albania',
#  'A0167': 'Albatross',
#  'A0168': 'Albert_Einstein',
#  'A0169': 'Alberto_Santos-Dumont',
#  'A0170': 'Albertosaurus',
#  'A0171': 'Albigensian_Crusade',
#  'A0172': 'Albinism',
#  'A0173': 'Albrecht_D%C3%BCrer',
#  'A0174': 'Albrecht_Rodenbach',
#  'A0175': 'Alchemy',
#  'A0176': 'Alcibiades',
#  'A0177': 'Alcohol',
#  'A0178': 'Aleksandr_Pushkin',
#  'A0179': 'Aleksandr_Vasilevsky',
#  'A0180': 'Aleksey_Arakcheyev',
#  'A0181': 'Alexander_Graham_Bell',
#  'A0182': 'Alexander_Hamilton',
#  'A0183': 'Alexander_the_Great',
#  'A0184': 'Alfred_Hitchcock',
#  'A0185': 'Alfred_Nobel',
#  'A0186': 'Alfred_the_Great',
#  'A0187': 'Algebra',
#  'A0188': 'Algeria',
#  'A0189': 'Algerian_Civil_War',
#  'A0190': 'Algiers',
#  'A0191': 'Algol',
#  'A0192': 'Algoma_Central_Railway',
#  'A0193': 'Algorithm',
#  'A0194': 'Alice%27s_Adventures_in_Wonderland',
#  'A0195': 'All_Blacks',
#  'A0196': 'All_You_Need_Is_Love_%28The_JAMs_song%29',
#  'A0197': 'All_your_base_are_belong_to_us',
#  'A0198': 'Allah',
#  'A0199': 'Allegory_in_the_Middle_Ages',
#  'A0200': 'Alligator',
#  'A0201': 'Alliterative_verse',
#  'A0202': 'Allosaurus',
#  'A0203': 'Almaty',
#  'A0204': 'Almond',
#  'A0205': 'Alpaca',
#  'A0206': 'Alphabet',
#  'A0207': 'Alternating_current',
#  'A0208': 'Alternation_of_generations',
#  'A0209': 'Alternative_rock',
#  'A0210': 'Aluminium',
#  'A0211': 'Aluminium_chloride',
#  'A0212': 'Alzheimer%27s_disease',
#  'A0213': 'Amaranth_oil',
#  'A0214': 'Amarillo%2C_Texas',
#  'A0215': 'Amazon_Basin',
#  'A0216': 'Amazon_Rainforest',
#  'A0217': 'Amazon_River',
#  'A0218': 'Amazon_parrot',
#  'A0219': 'Amber',
#  'A0220': 'Amda_Seyon_I',
#  'A0221': 'American_Civil_War',
#  'A0222': 'American_English',
#  'A0223': 'American_Revolutionary_War',
#  'A0224': 'American_Samoa',
#  'A0225': 'American_football',
#  'A0226': 'American_popular_music',
#  'A0227': 'Americium',
#  'A0228': 'Amish',
#  'A0229': 'Ammolite',
#  'A0230': 'Ammonia',
#  'A0231': 'Ammonite',
#  'A0232': 'Ammosaurus',
#  'A0233': 'Amsterdam',
#  'A0234': 'Amtrak',
#  'A0235': 'Amur',
#  'A0236': 'Anaconda',
#  'A0237': 'Analytical_Marxism',
#  'A0238': 'Anarchism',
#  'A0239': 'Anarcho-capitalism',
#  'A0240': 'Anatomy',
#  'A0241': 'Ancient_Egypt',
#  'A0242': 'Ancient_Greece',
#  'A0243': 'Ancient_Rome',
#  'A0244': 'Ancient_history',
#  'A0245': 'Andes',
#  'A0246': 'Andorra',
#  'A0247': 'Andr%C3%A9s_Nocioni',
#  'A0248': 'Andrew_Carnegie',
#  'A0249': 'Andrew_Dickson_White',
#  'A0250': 'Andrew_Gonzalez',
#  'A0251': 'Andrew_Jackson',
#  'A0252': 'Andrew_Johnson',
#  'A0253': 'Andrew_Robinson',
#  'A0254': 'Andriyivskyy_Descent',
#  'A0255': 'Andromeda_Galaxy',
#  'A0256': 'Andy_Warhol',
#  'A0257': 'Anemia',
#  'A0258': 'Angel_shark',
#  'A0259': 'Angelica',
#  'A0260': 'Angkor',
#  'A0261': 'Angkor_Wat',
#  'A0262': 'Anglican_Church_of_Australia',
#  'A0263': 'Anglican_Communion',
#  'A0264': 'Anglicanism',
#  'A0265': 'Anglo-Saxon_literature',
#  'A0266': 'Angola',
#  'A0267': 'Anguilla',
#  'A0268': 'Animal',
#  'A0269': 'Animal_law',
#  'A0270': 'Animal_rights',
#  'A0271': 'Animation',
#  'A0272': 'Ankylosaurus',
#  'A0273': 'Ann_Arbor%2C_Michigan',
#  'A0274': 'Anna_Karenina',
#  'A0275': 'Anne_Frank',
#  'A0276': 'Anne_of_Great_Britain',
#  'A0277': 'Annibale_Bugnini',
#  'A0278': 'Anno_Domini',
#  'A0279': 'Anschluss',
#  'A0280': 'Ant',
#  'A0281': 'Antananarivo',
#  'A0282': 'Antarctic_Treaty_System',
#  'A0283': 'Antarctic_krill',
#  'A0284': 'Antarctica',
#  'A0285': 'Antarctosaurus',
#  'A0286': 'Anteater',
#  'A0287': 'Antelope',
#  'A0288': 'Anthony_van_Dyck',
#  'A0289': 'Anthropology',
#  'A0290': 'Antigua_and_Barbuda',
#  'A0291': 'Antimony',
#  'A0292': 'Antlion',
#  'A0293': 'Antoine_Lavoisier',
#  'A0294': 'Anton%C3%ADn_Dvo%C5%99%C3%A1k',
#  'A0295': 'Anton_Alexander_von_Werner',
#  'A0296': 'Antonio_Vivaldi',
#  'A0297': 'Antwerp',
#  'A0298': 'Apaochi',
#  'A0299': 'Apatosaurus',
#  'A0300': 'Ape',
#  'A0301': 'Aphid',
#  'A0302': 'Apollo',
#  'A0303': 'Apollo_11',
#  'A0304': 'Apollo_8',
#  'A0305': 'Apostolic_Succession',
#  'A0306': 'Apple',
#  'A0307': 'Applied_mathematics',
#  'A0308': 'Apricot',
#  'A0309': 'Aquarium',
#  'A0310': 'Arab-Israeli_conflict',
#  'A0311': 'Arab_League',
#  'A0312': 'Arabic_language',
#  'A0313': 'Arable_land',
#  'A0314': 'Aradia%2C_or_the_Gospel_of_the_Witches',
#  'A0315': 'Aral_Sea',
#  'A0316': 'Arcadia_%28play%29',
#  'A0317': 'Archaeoastronomy',
#  'A0318': 'Archaeology',
#  'A0319': 'Archaeopteryx',
#  'A0320': 'Archbishop_of_Canterbury',
#  'A0321': 'Archimedes',
#  'A0322': 'Architecture',
#  'A0323': 'Architecture_of_Windows_NT',
#  'A0324': 'Architecture_of_the_California_missions',
#  'A0325': 'Arctic',
#  'A0326': 'Arctic_Circle',
#  'A0327': 'Arctic_Monkeys',
#  'A0328': 'Arctic_Ocean',
#  'A0329': 'Arctic_Tern',
#  'A0330': 'Arecaceae',
#  'A0331': 'Argan',
#  'A0332': 'Argentina',
#  'A0333': 'Argon',
#  'A0334': 'Argyle_diamond_mine',
#  'A0335': 'Ariel_Sharon',
#  'A0336': 'Aristarchus_%28crater%29',
#  'A0337': 'Aristotle',
#  'A0338': 'Arithmetic',
#  'A0339': 'Armadillo',
#  'A0340': 'Armand_Jean_du_Plessis%2C_Cardinal_Richelieu',
#  'A0341': 'Armenia',
#  'A0342': 'Armia_Krajowa',
#  'A0343': 'Arnold_Schwarzenegger',
#  'A0344': 'Arp2_3_complex',
#  'A0345': 'Ars_moriendi',
#  'A0346': 'Arsenal_F.C.',
#  'A0347': 'Arsenic',
#  'A0348': 'Art',
#  'A0349': 'Arthropod',
#  'A0350': 'Arthur_Ernest_Percival',
#  'A0351': 'Arthur_Sullivan',
#  'A0352': 'Arthur_Upfield',
#  'A0353': 'Arthur_Wellesley%2C_1st_Duke_of_Wellington',
#  'A0354': 'Arts_and_crafts',
#  'A0355': 'Aruba',
#  'A0356': 'Arugula',
#  'A0357': 'Ascariasis',
#  'A0358': 'Asia',
#  'A0359': 'Asp_%28reptile%29',
#  'A0360': 'Asparagus',
#  'A0361': 'Asperger_syndrome',
#  'A0362': 'Assyria',
#  'A0363': 'Astatine',
#  'A0364': 'Asteroid',
#  'A0365': 'Asthma',
#  'A0366': 'Astrology',
#  'A0367': 'Astronomy',
#  'A0368': 'Astrophysics_Data_System',
#  'A0369': 'Asunci%C3%B3n',
#  'A0370': 'Ateneo_de_Manila_University',
#  'A0371': 'Athanasius_Kircher',
#  'A0372': 'Atheism',
#  'A0373': 'Athena',
#  'A0374': 'Athens',
#  'A0375': 'Athletics_%28track_and_field%29',
#  'A0376': 'Atlanta%2C_Georgia',
#  'A0377': 'Atlantic_Coast_Line_Railroad',
#  'A0378': 'Atlantic_Ocean',
#  'A0379': 'Atlantic_herring',
#  'A0380': 'Atlantic_slave_trade',
#  'A0381': 'Atlantis',
#  'A0382': 'Atom',
#  'A0383': 'Atonality',
#  'A0384': 'Attack_on_Pearl_Harbor',
#  'A0385': 'Attalus_I',
#  'A0386': 'Attention-deficit_hyperactivity_disorder',
#  'A0387': 'Attila_the_Hun',
#  'A0388': 'Auckland',
#  'A0389': 'Augusta%2C_Lady_Gregory',
#  'A0390': 'Augustan_literature',
#  'A0391': 'Auguste_Rodin',
#  'A0392': 'Augustine_of_Hippo',
#  'A0393': 'Augustus',
#  'A0394': 'Australia',
#  'A0395': 'Australian_English',
#  'A0396': 'Australian_Green_Tree_Frog',
#  'A0397': 'Australian_Open',
#  'A0398': 'Australian_Ringneck',
#  'A0399': 'Australian_constitutional_law',
#  'A0400': 'Australian_rules_football',
#  'A0401': 'Austria',
#  'A0402': 'Autism',
#  'A0403': 'Auto_racing',
#  'A0404': 'Autobianchi_Primula',
#  'A0405': 'Autocracy',
#  'A0406': 'Automated_teller_machine',
#  'A0407': 'Automatic_number_plate_recognition',
#  'A0408': 'Automobile',
#  'A0409': 'Autorack',
#  'A0410': 'Autostereogram',
#  'A0411': 'Autumn',
#  'A0412': 'Avacha_Volcano',
#  'A0413': 'Avalanche',
#  'A0414': 'Avatar__The_Last_Airbender',
#  'A0415': 'Avocado',
#  'A0416': 'Avon_Gorge',
#  'A0417': 'Avro_Lancaster',
#  'A0418': 'Axe',
#  'A0419': 'Ayaan_Hirsi_Ali',
#  'A0420': 'Aye-aye',
#  'A0421': 'Aymer_de_Valence%2C_2nd_Earl_of_Pembroke',
#  'A0422': 'Azerbaijan',
#  'A0423': 'Azerbaijani_people',
#  'A0424': 'Aztec',
#  'A0425': 'BAE_Systems',
#  'A0426': 'BASIC',
#  'A0427': 'BBC',
#  'A0428': 'BBC_television_drama',
#  'A0429': 'BP',
#  'A0430': 'BT_Tower',
#  'A0431': 'B_vitamins',
#  'A0432': 'Babe_Ruth',
#  'A0433': 'Baboon',
#  'A0434': 'Babur',
#  'A0435': 'Baby_Gender_Mentor',
#  'A0436': 'Babylonia',
#  'A0437': 'Backgammon',
#  'A0438': 'Bacteria',
#  'A0439': 'Baden-Powell_House',
#  'A0440': 'Badger',
#  'A0441': 'Badminton',
#  'A0442': 'Badugi',
#  'A0443': 'Baghdad',
#  'A0444': 'Bah%C3%A1%27%C3%AD_Faith',
#  'A0445': 'Bahamas',
#  'A0446': 'Bahrain',
#  'A0447': 'Baker_Island',
#  'A0448': 'Bald_Eagle',
#  'A0449': 'Baltic_Sea',
#  'A0450': 'Baltimore%2C_Maryland',
#  'A0451': 'Bamako',
#  'A0452': 'Banana',
#  'A0453': 'Bandicoot',
#  'A0454': 'Bangalore',
#  'A0455': 'Bangkok',
#  'A0456': 'Bangladesh',
#  'A0457': 'Banjul',
#  'A0458': 'Bank_of_China_%28Hong_Kong%29',
#  'A0459': 'Banknote',
#  'A0460': 'Banksy',
#  'A0461': 'Bantu',
#  'A0462': 'Barack_Obama',
#  'A0463': 'Barbados',
#  'A0464': 'Barbara_McClintock',
#  'A0465': 'Barbary_Lion',
#  'A0466': 'Barbary_Macaque',
#  'A0467': 'Barcelona',
#  'A0468': 'Barium',
#  'A0469': 'Barley',
#  'A0470': 'Barn_Owl',
#  'A0471': 'Barnacle',
#  'A0472': 'Baroque',
#  'A0473': 'Barracuda',
#  'A0474': 'Baruch_Spinoza',
#  'A0475': 'Baseball',
#  'A0476': 'Basel',
#  'A0477': 'Basil',
#  'A0478': 'Basil_Brush',
#  'A0479': 'Basilica_of_San_Francesco_d%27Assisi',
#  'A0480': 'Basilica_of_Santa_Maria_degli_Angeli',
#  'A0481': 'Basketball',
#  'A0482': 'Basking_shark',
#  'A0483': 'Bass_%28fish%29',
#  'A0484': 'Basset_Hound',
#  'A0485': 'Bassoon',
#  'A0486': 'Bat',
#  'A0487': 'Bat-eared_Fox',
#  'A0488': 'Bath%2C_Somerset',
#  'A0489': 'Bath_School_disaster',
#  'A0490': 'Batholith',
#  'A0491': 'Batman',
#  'A0492': 'Battle_of_Alesia',
#  'A0493': 'Battle_of_Amiens',
#  'A0494': 'Battle_of_Austerlitz',
#  'A0495': 'Battle_of_Badr',
#  'A0496': 'Battle_of_Bicocca',
#  'A0497': 'Battle_of_Britain',
#  'A0498': 'Battle_of_Cannae',
#  'A0499': 'Battle_of_France',
#  'A0500': 'Battle_of_Gettysburg',
#  'A0501': 'Battle_of_Grunwald',
#  'A0502': 'Battle_of_Hastings',
#  'A0503': 'Battle_of_Jutland',
#  'A0504': 'Battle_of_Lechaeum',
#  'A0505': 'Battle_of_Leyte_Gulf',
#  'A0506': 'Battle_of_Marathon',
#  'A0507': 'Battle_of_Midway',
#  'A0508': 'Battle_of_Moscow',
#  'A0509': 'Battle_of_Normandy',
#  'A0510': 'Battle_of_Rennell_Island',
#  'A0511': 'Battle_of_Sitka',
#  'A0512': 'Battle_of_Smolensk_%281943%29',
#  'A0513': 'Battle_of_Stalingrad',
#  'A0514': 'Battle_of_Tours',
#  'A0515': 'Battle_of_Vaslui',
#  'A0516': 'Battle_of_Warsaw_%281920%29',
#  'A0517': 'Battle_of_the_Bulge',
#  'A0518': 'Battle_of_the_Eastern_Solomons',
#  'A0519': 'Battle_of_the_Little_Bighorn',
#  'A0520': 'Battle_of_the_Santa_Cruz_Islands',
#  'A0521': 'Battle_of_the_Somme_%281916%29',
#  'A0522': 'Battles_of_the_Mexican-American_War',
#  'A0523': 'Bay_Area_Rapid_Transit',
#  'A0524': 'Bay_of_Bengal',
#  'A0525': 'Beach',
#  'A0526': 'Bean',
#  'A0527': 'Bear',
#  'A0528': 'Beatles_for_Sale',
#  'A0529': 'Beaver',
#  'A0530': 'Bedbug',
#  'A0531': 'Bede',
#  'A0532': 'Bee',
#  'A0533': 'Beeching_Axe',
#  'A0534': 'Beekeeping',
#  'A0535': 'Beep_%28SWBLW%29',
#  'A0536': 'Beer',
#  'A0537': 'Beet',
#  'A0538': 'Beetle',
#  'A0539': 'Behavioral_finance',
#  'A0540': 'Behistun_Inscription',
#  'A0541': 'Beijing',
#  'A0542': 'Beirut',
#  'A0543': 'Belarus',
#  'A0544': 'Belfast',
#  'A0545': 'Belgium',
#  'A0546': 'Belize',
#  'A0547': 'Belton_House',
#  'A0548': 'Ben-Hur_%281959_film%29',
#  'A0549': 'Ben_Jonson',
#  'A0550': 'Ben_Nevis',
#  'A0551': 'Bench_language',
#  'A0552': 'Benin',
#  'A0553': 'Benito_Mussolini',
#  'A0554': 'Benjamin_Britten',
#  'A0555': 'Benjamin_Disraeli%2C_1st_Earl_of_Beaconsfield',
#  'A0556': 'Benjamin_Franklin',
#  'A0557': 'Benjamin_Harrison',
#  'A0558': 'Benjamin_Mountfort',
#  'A0559': 'Benjamin_of_Tudela',
#  'A0560': 'Benzene',
#  'A0561': 'Berber_languages',
#  'A0562': 'Beriberi',
#  'A0563': 'Berkelium',
#  'A0564': 'Berlin',
#  'A0565': 'Berlin_Wall',
#  'A0566': 'Bermuda',
#  'A0567': 'Bernard_Hinault',
#  'A0568': 'Bertrand_Russell',
#  'A0569': 'Beryllium',
#  'A0570': 'Betelgeuse_incident',
#  'A0571': 'Bette_Davis',
#  'A0572': 'Bhutan',
#  'A0573': 'Bible',
#  'A0574': 'Bicycle',
#  'A0575': 'Bicycle_Thieves',
#  'A0576': 'Big_Bang',
#  'A0577': 'Bill_Clinton',
#  'A0578': 'Bill_Gates',
#  'A0579': 'Billie_Holiday',
#  'A0580': 'Binary_star',
#  'A0581': 'Binoculars',
#  'A0582': 'Binomial_nomenclature',
#  'A0583': 'Biodiesel',
#  'A0584': 'Biodiversity',
#  'A0585': 'Biofuel',
#  'A0586': 'Bioinformatics',
#  'A0587': 'Biology',
#  'A0588': 'Bionicle__Mask_of_Light',
#  'A0589': 'Biosphere',
#  'A0590': 'Biotechnology',
#  'A0591': 'Bird',
#  'A0592': 'Bird_migration',
#  'A0593': 'Bird_of_prey',
#  'A0594': 'Birmingham',
#  'A0595': 'Birth_control',
#  'A0596': 'Bismuth',
#  'A0597': 'Bison',
#  'A0598': 'Bissau',
#  'A0599': 'Bj%C3%B6rn_Borg',
#  'A0600': 'Bj%C3%B8rn%C3%B8ya',
#  'A0601': 'Black-backed_Jackal',
#  'A0602': 'Black-footed_Cat',
#  'A0603': 'Black-winged_Stilt',
#  'A0604': 'Black_Death',
#  'A0605': 'Black_Rhinoceros',
#  'A0606': 'Black_Robin',
#  'A0607': 'Black_Sea',
#  'A0608': 'Black_Seminoles',
#  'A0609': 'Black_Wildebeest',
#  'A0610': 'Black_hole',
#  'A0611': 'Black_panther',
#  'A0612': 'Black_pepper',
#  'A0613': 'Black_widow_spider',
#  'A0614': 'Blackbird',
#  'A0615': 'Blackcap',
#  'A0616': 'Blackjack',
#  'A0617': 'Blackpool',
#  'A0618': 'Blacktip_reef_shark',
#  'A0619': 'Blade_Runner',
#  'A0620': 'Blaise_Pascal',
#  'A0621': 'Blitzkrieg',
#  'A0622': 'Blokus',
#  'A0623': 'Blood_type',
#  'A0624': 'Blue_Jay',
#  'A0625': 'Blue_Peter',
#  'A0626': 'Blue_Tit',
#  'A0627': 'Blue_Whale',
#  'A0628': 'Blue_Wildebeest',
#  'A0629': 'Blue_shark',
#  'A0630': 'Bluegrass_music',
#  'A0631': 'Bluetooth',
#  'A0632': 'Boa',
#  'A0633': 'Board_game',
#  'A0634': 'Boat',
#  'A0635': 'Bob_Dylan',
#  'A0636': 'Bob_Marley',
#  'A0637': 'Bobcat',
#  'A0638': 'Body_mass_index',
#  'A0639': 'Bodyline',
#  'A0640': 'Boeing_747',
#  'A0641': 'Bog',
#  'A0642': 'Bogot%C3%A1',
#  'A0643': 'Bohemian_Rhapsody',
#  'A0644': 'Bohor_Reedbuck',
#  'A0645': 'Bohrium',
#  'A0646': 'Bolivia',
#  'A0647': 'Bologna',
#  'A0648': 'Boltysh_crater',
#  'A0649': 'Bongo_%28antelope%29',
#  'A0650': 'Bonobo',
#  'A0651': 'Bontebok',
#  'A0652': 'Booby',
#  'A0653': 'Book',
#  'A0654': 'Book_of_Common_Prayer',
#  'A0655': 'Book_of_Kells',
#  'A0656': 'Boolean_logic',
#  'A0657': 'Borage',
#  'A0658': 'Boris_Becker',
#  'A0659': 'Boron',
#  'A0660': 'Bosnia_and_Herzegovina',
#  'A0661': 'Boston%2C_Massachusetts',
#  'A0662': 'Boston_RFC',
#  'A0663': 'Boston_Terrier',
#  'A0664': 'Boston_and_Lowell_Railroad',
#  'A0665': 'Botany',
#  'A0666': 'Botswana',
#  'A0667': 'Bottlenose_Dolphin',
#  'A0668': 'Boudica',
#  'A0669': 'Boundary_Waters_Canoe_Area_Wilderness',
#  'A0670': 'Bourbonnais_train_accident',
#  'A0671': 'Bouvet_Island',
#  'A0672': 'Box_jellyfish',
#  'A0673': 'Boy_Scout',
#  'A0674': 'Boyle_Roche',
#  'A0675': 'Brabantian',
#  'A0676': 'Brabham',
#  'A0677': 'Brachiosaurus',
#  'A0678': 'Brahman',
#  'A0679': 'Brain',
#  'A0680': 'Bran',
#  'A0681': 'Brandon_Routh',
#  'A0682': 'Bras%C3%ADlia',
#  'A0683': 'Brass_instrument',
#  'A0684': 'Bratislava',
#  'A0685': 'Brazil',
#  'A0686': 'Bread',
#  'A0687': 'Breaker_Morant',
#  'A0688': 'Bretton_Woods_system',
#  'A0689': 'Brian_Close',
#  'A0690': 'Bridge',
#  'A0691': 'Brighton',
#  'A0692': 'Brisbane',
#  'A0693': 'Bristol',
#  'A0694': 'British_East_India_Company',
#  'A0695': 'British_Empire',
#  'A0696': 'British_English',
#  'A0697': 'British_House_of_Commons',
#  'A0698': 'British_Indian_Ocean_Territory',
#  'A0699': 'British_Isles',
#  'A0700': 'British_Isles_%28terminology%29',
#  'A0701': 'British_Virgin_Islands',
#  'A0702': 'British_monarchy',
#  'A0703': 'Britney_Spears',
#  'A0704': 'Broadcasting',
#  'A0705': 'Bromine',
#  'A0706': 'Bronze_Age',
#  'A0707': 'Brothers_Grimm',
#  'A0708': 'Brown_trout',
#  'A0709': 'Bruce_Lee',
#  'A0710': 'Bruce_Springsteen',
#  'A0711': 'Brunei',
#  'A0712': 'Brush',
#  'A0713': 'Brussels',
#  'A0714': 'Brute_force_attack',
#  'A0715': 'Bryce_Canyon_National_Park',
#  'A0716': 'Btrieve',
#  'A0717': 'Bucharest',
#  'A0718': 'Buckingham_Palace',
#  'A0719': 'Buckminster_Fuller',
#  'A0720': 'Budapest',
#  'A0721': 'Buddha',
#  'A0722': 'Buddhism',
#  'A0723': 'Buddhist_art',
#  'A0724': 'Buenos_Aires',
#  'A0725': 'Buffy_the_Vampire_Slayer',
#  'A0726': 'Bulgaria',
#  'A0727': 'Bull_shark',
#  'A0728': 'Burkina_Faso',
#  'A0729': 'Burundi',
#  'A0730': 'Bushbuck',
#  'A0731': 'Bushpig',
#  'A0732': 'Business',
#  'A0733': 'Butter',
#  'A0734': 'Button',
#  'A0735': 'Byzantine_Empire',
#  'A0736': 'C%2B%2B',
#  'A0737': 'C%C3%A6dmon',
#  'A0738': 'C%C3%B4te_d%27Ivoire',
#  'A0739': 'C._S._Lewis',
#  'A0740': 'CF7',
#  'A0741': 'CPU_cache',
#  'A0742': 'CS_gas',
#  'A0743': 'Cactus',
#  'A0744': 'Cadmium',
#  'A0745': 'Caesar_cipher',
#  'A0746': 'Caesium',
#  'A0747': 'Caesium_fluoride',
#  'A0748': 'Cai_Lun',
#  'A0749': 'Cairo',
#  'A0750': 'Calcite',
#  'A0751': 'Calcium',
#  'A0752': 'Calcium_chloride',
#  'A0753': 'Calculus',
#  'A0754': 'Calgary',
#  'A0755': 'California',
#  'A0756': 'California_Southern_Railroad',
#  'A0757': 'Californium',
#  'A0758': 'Calligraphy',
#  'A0759': 'Caloris_Basin',
#  'A0760': 'Calvin_Coolidge',
#  'A0761': 'Calvin_and_Hobbes',
#  'A0762': 'Camarasaurus',
#  'A0763': 'Cambodia',
#  'A0764': 'Cambrian',
#  'A0765': 'Cambrian_explosion',
#  'A0766': 'Cambridge',
#  'A0767': 'Camel',
#  'A0768': 'Cameroon',
#  'A0769': 'Canada',
#  'A0770': 'Canada_Goose',
#  'A0771': 'Canadian_Charter_of_Rights_and_Freedoms',
#  'A0772': 'Canadian_English',
#  'A0773': 'Canadian_House_of_Commons',
#  'A0774': 'Canadian_Pacific_Railway',
#  'A0775': 'Canadian_Senate',
#  'A0776': 'Canadian_football',
#  'A0777': 'Canal',
#  'A0778': 'Canaletto',
#  'A0779': 'Canberra',
#  'A0780': 'Cancer',
#  'A0781': 'Cane_Toad',
#  'A0782': 'Canola',
#  'A0783': 'Canterbury',
#  'A0784': 'Canterbury_Cathedral',
#  'A0785': 'Canute_the_Great',
#  'A0786': 'Capacitance',
#  'A0787': 'Cape_Canaveral',
#  'A0788': 'Cape_Horn',
#  'A0789': 'Cape_Lion',
#  'A0790': 'Cape_Porcupine',
#  'A0791': 'Cape_Town',
#  'A0792': 'Cape_Verde',
#  'A0793': 'Capital',
#  'A0794': 'Capitalism',
#  'A0795': 'Capitoline_Triad',
#  'A0796': 'Captain_Marvel_%28DC_Comics%29',
#  'A0797': 'Caracas',
#  'A0798': 'Caratacus',
#  'A0799': 'Caravaggio',
#  'A0800': 'Carbon',
#  'A0801': 'Carbon_dioxide',
#  'A0802': 'Carboniferous',
#  'A0803': 'Carcinus_maenas',
#  'A0804': 'Card_game',
#  'A0805': 'Cardiff',
#  'A0806': 'Caribbean_Sea',
#  'A0807': 'Carl_Friedrich_Gauss',
#  'A0808': 'Carl_G._Fisher',
#  'A0809': 'Carl_Jung',
#  'A0810': 'Carl_Lewis',
#  'A0811': 'Carl_Sagan',
#  'A0812': 'Carlsbad_Caverns_National_Park',
#  'A0813': 'Carnivore',
#  'A0814': 'Caroline_Island',
#  'A0815': 'Carolingian_Gospel_Book_%28British_Library%2C_MS_Add._11848%29',
#  'A0816': 'Carolus_Linnaeus',
#  'A0817': 'Carrot',
#  'A0818': 'Casablanca_%28film%29',
#  'A0819': 'Casimir_effect',
#  'A0820': 'Caspian_Sea',
#  'A0821': 'Cassini-Huygens',
#  'A0822': 'Cassowary',
#  'A0823': 'Castra',
#  'A0824': 'Cat',
#  'A0825': 'Cat%27s_Eye_Nebula',
#  'A0826': 'Cat_Stevens',
#  'A0827': 'Cataract',
#  'A0828': 'Cataract_surgery',
#  'A0829': 'Cathedral_of_Magdeburg',
#  'A0830': 'Catherine_Cranston',
#  'A0831': 'Catherine_II_of_Russia',
#  'A0832': 'Catholic_social_teaching',
#  'A0833': 'Cattle',
#  'A0834': 'Cave',
#  'A0835': 'Cayman_Islands',
#  'A0836': 'Celeriac',
#  'A0837': 'Celery',
#  'A0838': 'Celine_Dion',
#  'A0839': 'Cell_%28biology%29',
#  'A0840': 'Cello',
#  'A0841': 'Celtic_F.C.',
#  'A0842': 'Celtic_Park',
#  'A0843': 'Celtic_mythology',
#  'A0844': 'Central_African_Republic',
#  'A0845': 'Central_processing_unit',
#  'A0846': 'Ceratopsidae',
#  'A0847': 'Cereal',
#  'A0848': 'Cerebellum',
#  'A0849': 'Ceres_%28dwarf_planet%29',
#  'A0850': 'Cerium',
#  'A0851': 'Chad',
#  'A0852': 'Chadian-Sudanese_conflict',
#  'A0853': 'Chaffinch',
#  'A0854': 'Channel_Islands',
#  'A0855': 'Charlemagne',
#  'A0856': 'Charles_Babbage',
#  'A0857': 'Charles_Darwin',
#  'A0858': 'Charles_Dickens',
#  'A0859': 'Charles_Etienne_Brasseur_de_Bourbourg',
#  'A0860': 'Charles_II_of_England',
#  'A0861': 'Charles_I_of_England',
#  'A0862': 'Charles_Sumner',
#  'A0863': 'Charles_V%2C_Holy_Roman_Emperor',
#  'A0864': 'Charlie_Chaplin',
#  'A0865': 'Charlotte%27s_Web',
#  'A0866': 'Chartism',
#  'A0867': 'Che_Guevara',
#  'A0868': 'Cheers',
#  'A0869': 'Cheese',
#  'A0870': 'Cheetah',
#  'A0871': 'Chelsea_F.C.',
#  'A0872': 'Chemical_element',
#  'A0873': 'Chemical_synapse',
#  'A0874': 'Chemistry',
#  'A0875': 'Chennai',
#  'A0876': 'Chepstow_Bridge',
#  'A0877': 'Chernobyl_disaster',
#  'A0878': 'Chess',
#  'A0879': 'Chester_A._Arthur',
#  'A0880': 'Chestnut',
#  'A0881': 'Chew_Magna',
#  'A0882': 'Chew_Stoke',
#  'A0883': 'Chew_Valley',
#  'A0884': 'Chew_Valley_Lake',
#  'A0885': 'Chicago',
#  'A0886': 'Chicago_Bears',
#  'A0887': 'Chicago_and_North_Western_Railway',
#  'A0888': 'Chicken',
#  'A0889': 'Child',
#  'A0890': 'Children%27s_Crusade',
#  'A0891': 'Children%27s_rights_movement',
#  'A0892': 'Chile',
#  'A0893': 'Chiltern_Hills',
#  'A0894': 'Chimpanzee',
#  'A0895': 'China',
#  'A0896': 'Chinese_Rites_controversy',
#  'A0897': 'Chinese_language',
#  'A0898': 'Chinyingi',
#  'A0899': 'Chives',
#  'A0900': 'Chlorine',
#  'A0901': 'Chocolate',
#  'A0902': 'Chola_dynasty',
#  'A0903': 'Cholera',
#  'A0904': 'Chordate',
#  'A0905': 'Chris_Evert',
#  'A0906': 'Christian_Bale',
#  'A0907': 'Christian_monasticism',
#  'A0908': 'Christianity',
#  'A0909': 'Christina_Aguilera',
#  'A0910': 'Christmas_Island',
#  'A0911': 'Christopher_Columbus',
#  'A0912': 'Christopher_Wren',
#  'A0913': 'Chromatic_aberration',
#  'A0914': 'Chromatophore',
#  'A0915': 'Chromium',
#  'A0916': 'Church_of_England',
#  'A0917': 'Church_of_Ireland',
#  'A0918': 'Cicely',
#  'A0919': 'Cider',
#  'A0920': 'Cinema_of_the_United_States',
#  'A0921': 'Citizen_Kane',
#  'A0922': 'Citizenship',
#  'A0923': 'Citrus',
#  'A0924': 'City',
#  'A0925': 'City_status_in_the_United_Kingdom',
#  'A0926': 'Civil_War_token',
#  'A0927': 'Civil_rights',
#  'A0928': 'Civil_society',
#  'A0929': 'Civilization',
#  'A0930': 'Civilization_%28computer_game%29',
#  'A0931': 'Clarinet',
#  'A0932': 'Classic_female_blues',
#  'A0933': 'Claude_L%C3%A9vi-Strauss',
#  'A0934': 'Claude_Monet',
#  'A0935': 'Claudius',
#  'A0936': 'Clay',
#  'A0937': 'Cleopatra_VII',
#  'A0938': 'Cleopatra_VII_of_Egypt',
#  'A0939': 'Cleveland%2C_Ohio',
#  'A0940': 'Clifton_Suspension_Bridge',
#  'A0941': 'Climate',
#  'A0942': 'Climate_change',
#  'A0943': 'Clock',
#  'A0944': 'Clone_Wars_%28Star_Wars%29',
#  'A0945': 'Clothing',
#  'A0946': 'Cloud',
#  'A0947': 'Coal',
#  'A0948': 'Coal_Tit',
#  'A0949': 'Cobalt',
#  'A0950': 'Coccinellidae',
#  'A0951': 'Cochineal',
#  'A0952': 'Cockatiel',
#  'A0953': 'Cocoa',
#  'A0954': 'Coconut',
#  'A0955': 'Coconut_crab',
#  'A0956': 'Coconut_oil',
#  'A0957': 'Cocos_%28Keeling%29_Islands',
#  'A0958': 'Cod',
#  'A0959': 'Code_of_Hammurabi',
#  'A0960': 'Coffee',
#  'A0961': 'Coin',
#  'A0962': 'Cold_War',
#  'A0963': 'Colditz_Castle',
#  'A0964': 'Colima_%28volcano%29',
#  'A0965': 'Collapse_of_the_World_Trade_Center',
#  'A0966': 'Colley_Cibber',
#  'A0967': 'Cologne',
#  'A0968': 'Colombia',
#  'A0969': 'Colombo',
#  'A0970': 'Color',
#  'A0971': 'Color_Graphics_Adapter',
#  'A0972': 'Color_blindness',
#  'A0973': 'Colorado_River',
#  'A0974': 'Colossus_of_Rhodes',
#  'A0975': 'Columba',
#  'A0976': 'Columbia_River',
#  'A0977': 'Columbine_High_School_massacre',
#  'A0978': 'Columbus%2C_Ohio',
#  'A0979': 'Comet',
#  'A0980': 'Comet_Hale-Bopp',
#  'A0981': 'Comet_Halley',
#  'A0982': 'Comet_Hyakutake',
#  'A0983': 'Comet_Shoemaker-Levy_9',
#  'A0984': 'Comet_White-Ortiz-Bolelli',
#  'A0985': 'Comics',
#  'A0986': 'Comma_Johanneum',
#  'A0987': 'Commodore_64',
#  'A0988': 'Common_Basilisk',
#  'A0989': 'Common_Cuckoo',
#  'A0990': 'Common_Eider',
#  'A0991': 'Common_Eland',
#  'A0992': 'Common_Hazel',
#  'A0993': 'Common_Pheasant',
#  'A0994': 'Common_Tern',
#  'A0995': 'Common_agouti',
#  'A0996': 'Common_cold',
#  'A0997': 'Common_sage',
#  'A0998': 'Commonwealth_Games',
#  'A0999': 'Communication',
#  'A1000': 'Communism',
#  ...}

# %%
artspdict=dict()#article shortest path dict

# %%
fil="wikispeedia_paths-and-graph/wikispeedia_paths-and-graph/shortest-path-distance-matrix.txt"
with open(fil) as f:
        j=0
        for line in f:
            artspdict[articleidlist[j]]=line
            j+=1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-a58acc6f7341> in <module>
#       1 fil="wikispeedia_paths-and-graph/wikispeedia_paths-and-graph/shortest-path-distance-matrix.txt"
# ----> 2 with open(fil) as f:
#       3         j=0
#       4         for line in f:
#       5             artspdict[articleidlist[j]]=line
#
# FileNotFoundError: [Errno 2] No such file or directory: 'wikispeedia_paths-and-graph/wikispeedia_paths-and-graph/shortest-path-distance-matrix.txt'

# %%
#artspdict['A0001'][144]

# %% [raw]
# #actual logic
# #for i in finpathlist:
# i=finpathlist[10]
# path=i.split(";")
# if '<' not in path:
#     print(path)
# else:
#     print("crct")
# humanlength=len(path)
# print("hl",humanlength)
# pathstart=path[0]
# print("ps",pathstart)
# pathend=path[humanlength-1]
# print("pe",pathend)
# articlestart=artid_dict[pathstart]
# print("asid",articlestart)
# articleend=artid_dict[pathend]
# print("aeid",articleend)
# articleend=int(articleend[1:])
# print(articleend)
# shortestpath=artspdict[articlestart][articleend-1]
# print(shortestpath)

# %%
zl=lol=0
with open('finished-paths-back.csv', mode='a',newline='') as csv_file:
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(["path","humanlength","shortestpath","hl/spratio"])
    for i in finpathlist:
        path=i.split(";")
        #humanlength=len(path)
        #if "<" in path:
            #continue
        #else:
        humanlength=len(path)-1
        pathstart=path[0]
        pathend=path[humanlength]
        articlestartid=artid_dict[pathstart]
        articleendid=artid_dict[pathend]
        articleendid=int(articleendid[1:])
        shortestpath=artspdict[articlestartid][articleendid-1]
        if shortestpath == '_' :
            ratio='nan'
            shortestpath=0
            #lol+=1
           # print(path)
        elif shortestpath == '0':
                ratio='0'
                shortestpath=0
            #    zl+=1
           #     print(path,shortestpath)
            #else:
            #print(pathstart,"-",pathend,"",shortestpath)
        else:
            #print(path,humanlength,shortestpath)
            ratio=round(humanlength/int(shortestpath),2)
        csv_writer.writerow([i,humanlength,shortestpath,ratio])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-681c505bae2e> in <module>
#       4     csv_writer.writerow(["path","humanlength","shortestpath","hl/spratio"])
#       5     for i in finpathlist:
# ----> 6         path=i.split(";")
#       7         #humanlength=len(path)
#       8         #if "<" in path:
#
# AttributeError: 'float' object has no attribute 'split'

# %% [raw]
# 0/0

# %% [raw]
# zl=lol=0
# with open('finished-paths-no-back.csv', mode='a',newline='') as csv_file:
#     csv_writer = csv.writer(csv_file)
#     csv_writer.writerow(["path","humanlength","shortestpath","hl/spratio"])
#     for i in finpathlist:
#         path=i.split(";")
#         if "<" in path:
#             continue
#         else:
#             humanlength=len(path)
#             pathstart=path[0]
#             pathend=path[humanlength-1]
#             articlestartid=artid_dict[pathstart]
#             articleendid=artid_dict[pathend]
#             articleendid=int(articleendid[1:])
#             shortestpath=artspdict[articlestartid][articleendid-1]
#             if shortestpath == '_' :
#                 ratio='nan'
#                 lol+=1
#                 print(path)
#             elif shortestpath == '0':
#                 ratio='0'
#                 zl+=1
#                 print(path,shortestpath)
#             else:
#             #print(pathstart,"-",pathend,"",shortestpath)
#                 ratio=round(humanlength/int(shortestpath),2)
#             csv_writer.writerow([i,humanlength,shortestpath,ratio])

# %%
with open('finished-paths-no-back.csv', mode='a',newline='') as csv_file:
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(["path","humanlength","shortestpath","hl/spratio"])
    for i in finpathlist:
        path=i.split(";")
        
        stack = []
        for j in path:
            if j !='<':
                stack.append(i)
            elif j=='<':
                stack.pop()
        
        
        humanlength=(len(stack)-1)
        pathstart=path[0]
        pathend=path[len(path)-1]
        articlestartid=artid_dict[pathstart]
        articleendid=artid_dict[pathend]
        articleendid=int(articleendid[1:])
        shortestpath=artspdict[articlestartid][articleendid-1]
        if shortestpath == '_' :
            ratio='nan'
            shortestpath=0
            #lol+=1
           # print(path)
        elif shortestpath == '0':
                ratio='0'
                shortestpath=0
            #    zl+=1
           #     print(path,shortestpath)
            #else:
            #print(pathstart,"-",pathend,"",shortestpath)
        else:
            #print(path,humanlength,shortestpath)
            ratio=round(humanlength/int(shortestpath),2)
        
        
        csv_writer.writerow([i,humanlength,shortestpath,ratio])

# %% [raw]
# finpath=['14th_century;Time;Science;Nature;Weather;Sunlight;<;Sun;Earth%27s_atmosphere;Ultraviolet;Color;Light;Rainbow',
#         '14th_century;Europe;Republic_of_Ireland;<;<;Europe;<;Europe;Republic_of_Ireland;<;<;Time;Physics;Speed_of_light;Rainbow']
# for i in finpath:
#
#         path=i.split(";")
#         print(path)
#         stack = []
#         for i in path:
#             if i !='<':
#                 stack.append(i)
#             elif i=='<':
#                 stack.pop()
#
#         print(stack)
#         humanlength=(len(stack)-1)
#         print(humanlength)
#         pathstart=path[0]
#         pathend=path[len(path)-1]
#         articlestartid=artid_dict[pathstart]
#         articleendid=artid_dict[pathend]
#         articleendid=int(articleendid[1:])
#         shortestpath=artspdict[articlestartid][articleendid-1]
#         ratio=round(humanlength/int(shortestpath),2)
#         #csv_writer.writerow([i,humanlength,shortestpath,ratio])

# %% [raw]
# with open('finished-paths-back.csv', mode='a',newline='') as csv_file:
#     csv_writer = csv.writer(csv_file)
#     csv_writer.writerow(["path","humanlength","shortestpath","hl/spratio"])
#     for i in finpathlist:
#         path=i.split(";")
#         if "<" not in path:
#             continue
#         else:
#             humanlength=len(path)
#             pathstart=path[0]
#             pathend=path[humanlength-1]
#             articlestartid=artid_dict[pathstart]
#             articleendid=artid_dict[pathend]
#             articleendid=int(articleendid[1:])
#             shortestpath=artspdict[articlestartid][articleendid-1]
#             ratio=round(humanlength/int(shortestpath),2)
#             csv_writer.writerow([i,humanlength,shortestpath,ratio])

# %% [raw]
# 0/0

# %%
lol
# Out:
# 1

# %%
zl
# Out:
# 11
